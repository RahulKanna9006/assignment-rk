# %%
'''Note: 

* Before writing any code remember that this assigment is for helping you understand the basics of file
handling in csv file. 

* This project is designed to have a work flow such that everyone is in same page for this purpose the variables are
given a strict name which should not be changed or modified according to your convinience

* Few of new functions like .head() .xticks().... and concepts may have been introduced in the assingment, so we encourage you
all to go through them without skipping.

*  functions which are to be used in the Your code sections are globally available so try to look for those where you have been prompted
'''

'''Its the data of a meal delivery company which operates in multiple cities. 
They have various fulfillment centers in these cities for dispatching meal orders to their customers.
train.csv: Historical data of demand for a product-center combination 
fulfilment_center_info.csv: Information for fulfillment center like center area, city information etc.
meal_info.csv: Product(Meal) features such as category, sub-category, current price and discount'''


'''START CODE'''

#Import necessary libraries: Numpy,pandas,matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


'''************************Your code here**********************'''

'''************************************************************'''


#read meal_info.csv file from provided dataset into a df_meal named variable
#Note: Proper file directory should be provided
df_meal=pd.read_csv(r'C:\Users\User\Downloads\train_GzS76OK (1)\meal_info.csv')
df_meal


'''************************Your code here**********************'''

'''************************************************************'''


df_meal.head()'''This is for displaying first five data points'''

#read fulfilment_center_info.csv file from provided dataset
#Note: Proper file directory should be provided
df_center=pd.read_csv(r'C:\Users\User\Downloads\train_GzS76OK (1)\fulfilment_center_info.csv')
df_center

'''************************Your code here**********************'''

'''************************************************************'''

df_center.head()'''This is for displaying first five data points'''

#read train.csv file from provided dataset
#Note: Proper file directory should be provided

df_food=pd.read_csv(r'C:\Users\User\Downloads\train_GzS76OK (1)\train.csv')
df_food
'''************************Your code here**********************'''

'''************************************************************'''

df_food.head()

'''Since the provided information is in different files, your work here is to merge them.Look for the functions
in pandas library to do so'''
#fulfilment_center_info and trian
df = pd.merge(df_center, df_food, on= 'center_id') 
df
# for meal_info and merged one

df=pd.merge(df,df_meal,on='meal_id')
df

'''************************Your code here**********************'''


'''************************************************************'''

'''Here we have used pd.pivot_table() kindly go through the function and mention in comment what it does'''

table = pd.pivot_table(data=df,index='category',values='num_orders',aggfunc=np.sum)
# This fn creates a table of two columns first column will contain the all unique elements of column which is passed as 
# index and second column contains values f(all values for that elements which corresponds in column passed as values) 
# where f() is function passed as aggfunc, and by default it is np.mean()





'''Graph tweaking
************************
Plot a bar graph with title 'Most popular food' for category(x-axis) vs number-of-orders(y-axis)

give x label 'Food items'
give y label 'Quantity sold'


'''

'''************Yourcode*********************'''
x = np.array(table.index)
y = np.array(table.values)
y = np.array([y[i][0] for i in range(len(y))])
#bar graph

plt.bar(x,y)
#xticks 
plt.xticks(rotation=70) '''Write on comment what you feel this function does'''
//this function helps in reducing the space occupied by the x axis parameters

#x-axis labels 
plt.xlabel('Food items')

#y-axis labels 
plt.ylabel('Quantity sold')

#plot title 
plt.title('Most popular food')

#save plot 
plt.savefig('D:\\Most_popular_food.png')

#display 
plt.show()

'''************************************************'''


'''Comparison of weekly and monthly sales
 Create a new column
* named 'revenue' where each element is product of checkout_price and num_orders 
** named 'month' by using ['week'] column (week column value divided by 4 gives month value)'''

df['revenue']=(df['checkout_price']*df['num_orders'])
df['month']= df['week']//4

'''**************************Your code******************************'''



'''******************************************************************'''
'''Here we have created two list month and month_order ,
store month number in month list and revenue of each month in month_order'''
#list to store month-wise revenue 
table2 = pd.pivot_table(data=df,index=['month'],values=['revenue'],aggfunc=np.sum)
month=table2.index.tolist() 
month_order=table2['revenue'].tolist()

'''***********************************Your code***********************'''

    
'''*********************************************************************'''
'''Here we have created two list week and week_order ,you need to store in them mapping the monthly orders'''    
#list to store week-wise revenue 
table3= pd.pivot_table(data=df,index=['week'],values=['revenue'],aggfunc=np.sum)
week=table3.index.tolist()
week_order=table3['revenue'].tolist()

'''***********************************Your code***********************'''


'''*********************************************************************'''
''' Plot two subplots in the same space : one for weekly revenue and other for monthly revenue.
For weekly : Title(Weekly income),x_label(week),y_label(revenue); similarly for monthly revenue.
'''
fig,ax=plt.subplots(1,2,figsize=(20,5))
ax[1].plot(month,month_order)
ax[0].set_title('Weekly income')
ax[0].set_xlabel('Week')
ax[0].set_ylabel('Revenue')
ax[0].plot(week,week_order)
ax[1].set_xlabel('Month')
ax[1].set_ylabel('Revenue')
ax[1].set_title('Monthly income')

'''************Yourcode*********************'''



''' Display the plot'''
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_meal=pd.read_csv(r'C:\Users\User\Downloads\train_GzS76OK (1)\meal_info.csv')
df_meal
# Out:
#     meal_id      category      cuisine
# 0      1885     Beverages         Thai
# 1      1993     Beverages         Thai
# 2      2539     Beverages         Thai
# 3      1248     Beverages       Indian
# 4      2631     Beverages       Indian
# 5      1311        Extras         Thai
# 6      1062     Beverages      Italian
# 7      1778     Beverages      Italian
# 8      1803        Extras         Thai
# 9      1198        Extras         Thai
# 10     2707     Beverages      Italian
# 11     1847          Soup         Thai
# 12     1438          Soup         Thai
# 13     2494          Soup         Thai
# 14     2760  Other Snacks         Thai
# 15     2490         Salad      Italian
# 16     1109     Rice Bowl       Indian
# 17     2290     Rice Bowl       Indian
# 18     1525  Other Snacks         Thai
# 19     2704  Other Snacks         Thai
# 20     1878      Starters         Thai
# 21     2640      Starters         Thai
# 22     2577      Starters         Thai
# 23     1754      Sandwich      Italian
# 24     1971      Sandwich      Italian
# 25     2306         Pasta      Italian
# 26     2139     Beverages       Indian
# 27     2826      Sandwich      Italian
# 28     2664         Salad      Italian
# 29     2569         Salad      Italian
# 30     1230     Beverages  Continental
# 31     1207     Beverages  Continental
# 32     2322     Beverages  Continental
# 33     2492        Desert       Indian
# 34     1216         Pasta      Italian
# 35     1727     Rice Bowl       Indian
# 36     1902       Biryani       Indian
# 37     1247       Biryani       Indian
# 38     2304        Desert       Indian
# 39     1543        Desert       Indian
# 40     1770       Biryani       Indian
# 41     2126         Pasta      Italian
# 42     1558         Pizza  Continental
# 43     2581         Pizza  Continental
# 44     1962         Pizza  Continental
# 45     1571          Fish  Continental
# 46     2956          Fish  Continental
# 47     2104          Fish  Continental
# 48     2444       Seafood  Continental
# 49     2867       Seafood  Continental
# 50     1445       Seafood  Continental

# %%
df_center=pd.read_csv(r'C:\Users\User\Downloads\train_GzS76OK (1)\fulfilment_center_info.csv')
df_center
# Out:
#     center_id  city_code  region_code center_type  op_area
# 0          11        679           56      TYPE_A      3.7
# 1          13        590           56      TYPE_B      6.7
# 2         124        590           56      TYPE_C      4.0
# 3          66        648           34      TYPE_A      4.1
# 4          94        632           34      TYPE_C      3.6
# ..        ...        ...          ...         ...      ...
# 72         53        590           56      TYPE_A      3.8
# 73         30        604           56      TYPE_A      3.5
# 74         76        614           85      TYPE_A      3.0
# 75         68        676           34      TYPE_B      4.1
# 76         51        638           56      TYPE_A      7.0
#
# [77 rows x 5 columns]

# %%
df_food=pd.read_csv(r'C:\Users\User\Downloads\train_GzS76OK (1)\train.csv')
df_food
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders
# 0                           0                  0         177
# 1                           0                  0         270
# 2                           0                  0         189
# 3                           0                  0          54
# 4                           0                  0          40
# ...                       ...                ...         ...
# 456543                      0                  0          68
# 456544                      0                  0          42
# 456545                      0                  0         501
# 456546                      0                  0         729
# 456547                      0                  0         162
#
# [456548 rows x 9 columns]

# %%
df = pd.merge(df_center, df_food, on= 'center_id') 
df
# Out:
#         center_id  city_code  region_code center_type  op_area       id  week  \
# 0              11        679           56      TYPE_A      3.7  1103215     1
# 1              11        679           56      TYPE_A      3.7  1093939     1
# 2              11        679           56      TYPE_A      3.7  1120771     1
# 3              11        679           56      TYPE_A      3.7  1472938     1
# 4              11        679           56      TYPE_A      3.7  1136817     1
# ...           ...        ...          ...         ...      ...      ...   ...
# 456543         51        638           56      TYPE_A      7.0  1144476   145
# 456544         51        638           56      TYPE_A      7.0  1450789   145
# 456545         51        638           56      TYPE_A      7.0  1161535   145
# 456546         51        638           56      TYPE_A      7.0  1215794   145
# 456547         51        638           56      TYPE_A      7.0  1301857   145
#
#         meal_id  checkout_price  base_price  emailer_for_promotion  \
# 0          1885          136.83      136.83                      0
# 1          1993          133.89      133.89                      0
# 2          2539          133.86      135.86                      0
# 3          2139          339.50      436.53                      0
# 4          2631          251.23      251.23                      0
# ...         ...             ...         ...                    ...
# 456543     1543          485.03      486.03                      0
# 456544     2304          484.03      485.03                      0
# 456545     2664          240.56      322.07                      0
# 456546     2569          241.53      339.56                      0
# 456547     2490          291.03      290.03                      0
#
#         homepage_featured  num_orders
# 0                       0         959
# 1                       0        1052
# 2                       0         379
# 3                       0          54
# 4                       0          80
# ...                   ...         ...
# 456543                  0         150
# 456544                  0          80
# 456545                  1         634
# 456546                  1         473
# 456547                  0         325
#
# [456548 rows x 13 columns]

# %%
df=pd.merge(df,df_meal,on='meal_id')
df
# Out:
#         center_id  city_code  region_code center_type  op_area       id  week  \
# 0              11        679           56      TYPE_A      3.7  1103215     1
# 1              11        679           56      TYPE_A      3.7  1091356     2
# 2              11        679           56      TYPE_A      3.7  1195933     3
# 3              11        679           56      TYPE_A      3.7  1425602     4
# 4              11        679           56      TYPE_A      3.7  1249127     5
# ...           ...        ...          ...         ...      ...      ...   ...
# 456543         51        638           56      TYPE_A      7.0  1299079   141
# 456544         51        638           56      TYPE_A      7.0  1476667   142
# 456545         51        638           56      TYPE_A      7.0  1145930   143
# 456546         51        638           56      TYPE_A      7.0  1421507   144
# 456547         51        638           56      TYPE_A      7.0  1205895   145
#
#         meal_id  checkout_price  base_price  emailer_for_promotion  \
# 0          1885          136.83      136.83                      0
# 1          1885          133.86      135.86                      0
# 2          1885          135.86      133.86                      0
# 3          1885          134.86      135.86                      0
# 4          1885          146.53      146.53                      0
# ...         ...             ...         ...                    ...
# 456543     2104          592.73      590.73                      0
# 456544     2104          590.73      592.73                      0
# 456545     2104          590.73      590.73                      0
# 456546     2104          591.73      590.73                      0
# 456547     2104          641.23      640.23                      0
#
#         homepage_featured  num_orders   category      cuisine
# 0                       0         959  Beverages         Thai
# 1                       0        1054  Beverages         Thai
# 2                       0         891  Beverages         Thai
# 3                       0        1107  Beverages         Thai
# 4                       0         919  Beverages         Thai
# ...                   ...         ...        ...          ...
# 456543                  0          94       Fish  Continental
# 456544                  0          42       Fish  Continental
# 456545                  0          42       Fish  Continental
# 456546                  0          54       Fish  Continental
# 456547                  0          69       Fish  Continental
#
# [456548 rows x 15 columns]

# %%
table = pd.pivot_table(data=df,index='category',values='num_orders',aggfunc=np.sum)

# %%
x = np.array(table.index)
y = np.array(table.values)
y = np.array([y[i][0] for i in range(len(y))])

# %%
plt.bar(x,y)
plt.xlabel('Food items')
plt.ylabel('Quantity sold')
plt.xticks(rotation=70)
plt.title('Most popular food')
plt.show()

# %%
df['revenue']=(df['checkout_price']*df['num_orders'])
df['month']= df['week']//4

# %%
table2 = pd.pivot_table(data=df,index=['month'],values=['revenue'],aggfunc=np.sum)
month=table2.index.tolist() 
month_order=table2['revenue'].tolist()

# %%
table3= pd.pivot_table(data=df,index=['week'],values=['revenue'],aggfunc=np.sum)
week=table3.index.tolist()
week_order=table3['revenue'].tolist()

# %%
fig,ax=plt.subplots(1,2,figsize=(20,5))
ax[1].plot(month,month_order)
ax[0].set_title('Weekly income')
ax[0].set_xlabel('Week')
ax[0].set_ylabel('Revenue')
ax[0].plot(week,week_order)
ax[1].set_xlabel('Month')
ax[1].set_ylabel('Revenue')
ax[1].set_title('Monthly income')
# Out:
# Text(0.5, 1.0, 'Monthly income')
